# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#read in primary CSV file for movies on Netflix, Hulu, Prime Video, and Disney+
csv_file = "Resources/all_movies_on_platforms.csv"
all_platforms_df = pd.read_csv(csv_file)
all_platforms_df.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# 0  United States,United Kingdom  English,Japanese,French    148.0
# 1                 United States                  English    136.0
# 2                 United States                  English    149.0
# 3                 United States                  English    116.0
# 4      Italy,Spain,West Germany                  Italian    161.0

# %%
#read in CSV for Netflix Original movies
other_csv_file = "Resources/netflix_original_movie_data.csv"
netflix_df = pd.read_csv(other_csv_file)
netflix_df.head()
# Out:
#    Unnamed: 0                                             Title  \
# 0           0                               Beasts of No Nation
# 1           1                                  The Ridiculous 6
# 2           2  Crouching Tiger, Hidden Dragon: Sword of Destiny
# 3           3                             Pee-wee's Big Holiday
# 4           4                            Special Correspondents
#
#           Directed by                                        Produced by  \
# 0  Cary Joji Fukunaga  Amy Kaufman Cary Joji Fukunaga Daniela Taplin ...
# 1        Frank Coraci             Allen Covert Adam Sandler Ted Sarandos
# 2       Yuen Woo-ping                    Charlie Nguyen Harvey Weinstein
# 3            John Lee                    ['Judd Apatow', 'Paul Reubens']
# 4       Ricky Gervais  Chris Coen Aaron L. Gilbert Ricky Gervais Ted ...
#
#         Screenplay by                                           Based on  \
# 0  Cary Joji Fukunaga      ['Beasts of No Nation', 'by Uzodinma Iweala']
# 1                 NaN                                                NaN
# 2          John Fusco    ['Iron Knight, Silver Vase', 'by', 'Wang Dulu']
# 3                 NaN                                                NaN
# 4                 NaN  ['Envoyés très spéciaux', 'by Simon Michaël & ...
#
#                                             Starring  \
# 0  Idris Elba Abraham Attah Kurt Egyiawan Jude Ak...
# 1  Adam Sandler Terry Crews Jorge Garcia Taylor L...
# 2                           Donnie Yen Michelle Yeoh
# 3                ['Paul Reubens', 'Joe Manganiello']
# 4  Ricky Gervais Eric Bana Vera Farmiga Kevin Pol...
#
#                              Music by       Cinematography  \
# 0                           Dan Romer   Cary Joji Fukunaga
# 1  Rupert Gregson-Williams Elmo Weber          Dean Semler
# 2                  Shigeru Umebayashi  Newton Thomas Sigel
# 3                   Mark Mothersbaugh              Tim Orr
# 4                   Dickon Hinchliffe         Terry Stacey
#
#                              Edited by  ... Turkish Indonesian German  \
# 0  Mikkel E. G. Nielsen Pete Beaudreau  ...     NaN        NaN    NaN
# 1                          Tom Costain  ...     NaN        NaN    NaN
# 2                      Jeff Betancourt  ...     NaN        NaN    NaN
# 3                        Jeff Buchanan  ...     NaN        NaN    NaN
# 4                   Nicolas Chaudeurge  ...     NaN        NaN    NaN
#
#   Norwegian Polish Music Lyrics Book  Basis  Productions
# 0       NaN    NaN   NaN    NaN  NaN    NaN          NaN
# 1       NaN    NaN   NaN    NaN  NaN    NaN          NaN
# 2       NaN    NaN   NaN    NaN  NaN    NaN          NaN
# 3       NaN    NaN   NaN    NaN  NaN    NaN          NaN
# 4       NaN    NaN   NaN    NaN  NaN    NaN          NaN
#
# [5 rows x 48 columns]

# %%
#clean all_platforms
all_platforms_df = all_platforms_df.drop(columns = ["Unnamed: 0", "ID", "Year", "Age", "Type", "Country", "Language"])

# %%
#clean netflix
netflix_df = netflix_df[["Title"]].copy()
netflix_df.head()
# Out:
#                                               Title
# 0                               Beasts of No Nation
# 1                                  The Ridiculous 6
# 2  Crouching Tiger, Hidden Dragon: Sword of Destiny
# 3                             Pee-wee's Big Holiday
# 4                            Special Correspondents

# %%
all_platforms_df["IMDb"].mean()
# Out:
# 5.902751499412594

# %%
all_platforms_df.dropna()
# Out:
#                                 Title  IMDb Rotten Tomatoes  Netflix  Hulu  \
# 0                           Inception   8.8             87%        1     0
# 1                          The Matrix   8.7             87%        1     0
# 2              Avengers: Infinity War   8.5             84%        1     0
# 3                  Back to the Future   8.5             96%        1     0
# 4      The Good, the Bad and the Ugly   8.8             97%        1     0
# ...                               ...   ...             ...      ...   ...
# 16671          George of the Jungle 2   3.3             17%        0     0
# 16677                   That Darn Cat   4.7             13%        0     0
# 16687                          Kazaam   3.0              6%        0     0
# 16705                Meet the Deedles   4.1              7%        0     0
# 16719                      Pocahontas   5.3             55%        0     0
#
#        Prime Video  Disney+                       Directors  \
# 0                0        0               Christopher Nolan
# 1                0        0  Lana Wachowski,Lilly Wachowski
# 2                0        0         Anthony Russo,Joe Russo
# 3                0        0                 Robert Zemeckis
# 4                1        0                    Sergio Leone
# ...            ...      ...                             ...
# 16671            0        1                  David Grossman
# 16677            0        1                Robert Stevenson
# 16687            0        1             Paul Michael Glaser
# 16705            0        1                     Steve Boyum
# 16719            0        1      Mike Gabriel,Eric Goldberg
#
#                                                  Genres  Runtime
# 0                      Action,Adventure,Sci-Fi,Thriller    148.0
# 1                                         Action,Sci-Fi    136.0
# 2                               Action,Adventure,Sci-Fi    149.0
# 3                               Adventure,Comedy,Sci-Fi    116.0
# 4                                               Western    161.0
# ...                                                 ...      ...
# 16671                           Adventure,Comedy,Family     87.0
# 16677                      Comedy,Crime,Family,Thriller    116.0
# 16687                     Comedy,Family,Fantasy,Musical     93.0
# 16705                                     Comedy,Family     93.0
# 16719  Animation,Adventure,Drama,Family,Musical,Romance     81.0
#
# [5035 rows x 10 columns]

# %%
all_platforms_df['Rotten Tomatoes'] = all_platforms_df['Rotten Tomatoes'].str.replace('%', '')
all_platforms_df
# Out:
#                                 Title  IMDb Rotten Tomatoes  Netflix  Hulu  \
# 0                           Inception   8.8              87        1     0
# 1                          The Matrix   8.7              87        1     0
# 2              Avengers: Infinity War   8.5              84        1     0
# 3                  Back to the Future   8.5              96        1     0
# 4      The Good, the Bad and the Ugly   8.8              97        1     0
# ...                               ...   ...             ...      ...   ...
# 16739       The Ghosts of Buxley Hall   6.2             NaN        0     0
# 16740                  The Poof Point   4.7             NaN        0     0
# 16741           Sharks of Lost Island   5.7             NaN        0     0
# 16742              Man Among Cheetahs   6.6             NaN        0     0
# 16743                In Beaver Valley   NaN             NaN        0     0
#
#        Prime Video  Disney+                       Directors  \
# 0                0        0               Christopher Nolan
# 1                0        0  Lana Wachowski,Lilly Wachowski
# 2                0        0         Anthony Russo,Joe Russo
# 3                0        0                 Robert Zemeckis
# 4                1        0                    Sergio Leone
# ...            ...      ...                             ...
# 16739            0        1                    Bruce Bilson
# 16740            0        1                     Neal Israel
# 16741            0        1                    Neil Gelinas
# 16742            0        1            Richard Slater-Jones
# 16743            0        1                     James Algar
#
#                                  Genres  Runtime
# 0      Action,Adventure,Sci-Fi,Thriller    148.0
# 1                         Action,Sci-Fi    136.0
# 2               Action,Adventure,Sci-Fi    149.0
# 3               Adventure,Comedy,Sci-Fi    116.0
# 4                               Western    161.0
# ...                                 ...      ...
# 16739      Comedy,Family,Fantasy,Horror    120.0
# 16740              Comedy,Family,Sci-Fi     90.0
# 16741                       Documentary      NaN
# 16742                       Documentary      NaN
# 16743          Documentary,Short,Family     32.0
#
# [16744 rows x 10 columns]

# %%
all_platforms_df['Rotten Tomatoes'] = all_platforms_df['Rotten Tomatoes'].astype(str)

# %%
all_platforms_df["Rotten Tomatoes"].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1302         try:
# -> 1303             x = float(x)
#    1304         except ValueError:
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1306             try:
# -> 1307                 x = complex(x)
#    1308             except ValueError:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-11cc1e190427> in <module>
# ----> 1 all_platforms_df["Rotten Tomatoes"].mean()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11214         return self._reduce(
# > 11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#   11217
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      67             try:
#      68                 with np.errstate(invalid="ignore"):
# ---> 69                     return f(*args, **kwargs)
#      70             except ValueError as e:
#      71                 # we want to transform an object array
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     123                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     124             else:
# --> 125                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126
#     127             return result
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     540         dtype_count = dtype
#     541     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 542     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     543
#     544     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1308             except ValueError:
#    1309                 # e.g. "foo"
# -> 1310                 raise TypeError(f"Could not convert {x} to numeric")
#    1311     return x
#    1312
#
# TypeError: Could not convert ... to numeric
